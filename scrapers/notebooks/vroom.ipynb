# %%
import requests
import json
import pandas as pd
import time

datestr = time.strftime("%Y%m%d")

# %%
# create function to return .json results from carmax hidden API
def vroom(pagenum,per_page=25):
    options = dict(
        offset = pagenum*per_page-per_page,
        limit = per_page,
        )
    
#https://invsearch.vroomapi.com/v2/inventory?brand=vroom&sort=&offset=75&limit=25
    
    json_url = "https://invsearch.vroomapi.com/v2/inventory?\
                brand=vroom&\
                sort=&\
                offset={offset}&\
                limit={limit}".format(**options).replace(" ","")
      
    raw = requests.get(json_url).text
    data = json.loads(raw)
    
    return data

# %%
print("Beginning Vroom.com scrape...")

listings = vroom(1)['meta']['count'] # return results for first page
print("# Listings:",listings)

pages = listings//vroom(1)['meta']['limit']
print("# Pages:",pages)
# Out:
# Beginning Vroom.com scrape...
# # Listings: 3414
# # Pages: 136

# %%
cars = pd.DataFrame.from_dict(vroom(1)['data'][0]['attributes'], orient='index').T
cars = cars.iloc[0:0]
for page in range(0,pages): # pages
    print("Scraping page #",page)
    for listing in range(0,vroom(1)['meta']['limit']): # per page
        df = pd.DataFrame.from_dict(vroom(page+1)['data'][listing]['attributes'], orient='index').T
        cars = pd.concat([cars,df])
    print(cars.shape[0],'cars')
# Out:
# Scraping page # 0
# 25 cars
# Scraping page # 1
# 50 cars
# Scraping page # 2
# 75 cars
# Scraping page # 3
# 100 cars
# Scraping page # 4
# 125 cars
# Scraping page # 5
# 150 cars
# Scraping page # 6
# 175 cars
# Scraping page # 7
# 200 cars
# Scraping page # 8
# 225 cars
# Scraping page # 9
# 250 cars
# Scraping page # 10
# 275 cars
# Scraping page # 11
# 300 cars
# Scraping page # 12
# 325 cars
# Scraping page # 13
# 350 cars
# Scraping page # 14
# 375 cars
# Scraping page # 15
# 400 cars
# Scraping page # 16
# 425 cars
# Scraping page # 17
# 450 cars
# Scraping page # 18
# 475 cars
# Scraping page # 19
# 500 cars
# Scraping page # 20
# 525 cars
# Scraping page # 21
# 550 cars
# Scraping page # 22
# 575 cars
# Scraping page # 23
# 600 cars
# Scraping page # 24
# 625 cars
# Scraping page # 25
# 650 cars
# Scraping page # 26
# 675 cars
# Scraping page # 27
# 700 cars
# Scraping page # 28
# 725 cars
# Scraping page # 29
# 750 cars
# Scraping page # 30
# 775 cars
# Scraping page # 31
# 800 cars
# Scraping page # 32
# 825 cars
# Scraping page # 33
# 850 cars
# Scraping page # 34
# 875 cars
# Scraping page # 35
# 900 cars
# Scraping page # 36
# 925 cars
# Scraping page # 37
# 950 cars
# Scraping page # 38
# 975 cars
# Scraping page # 39
# 1000 cars
# Scraping page # 40
# 1025 cars
# Scraping page # 41
# 1050 cars
# Scraping page # 42
# 1075 cars
# Scraping page # 43
# 1100 cars
# Scraping page # 44
# 1125 cars
# Scraping page # 45
# 1150 cars
# Scraping page # 46
# 1175 cars
# Scraping page # 47
# 1200 cars
# Scraping page # 48
# 1225 cars
# Scraping page # 49
# 1250 cars
# Scraping page # 50
# 1275 cars
# Scraping page # 51
# 1300 cars
# Scraping page # 52
# 1325 cars
# Scraping page # 53
# 1350 cars
# Scraping page # 54
# 1375 cars
# Scraping page # 55
# 1400 cars
# Scraping page # 56
# 1425 cars
# Scraping page # 57
# 1450 cars
# Scraping page # 58
# 1475 cars
# Scraping page # 59
# 1500 cars
# Scraping page # 60
# 1525 cars
# Scraping page # 61
# 1550 cars
# Scraping page # 62
# 1575 cars
# Scraping page # 63
# 1600 cars
# Scraping page # 64
# 1625 cars
# Scraping page # 65
# 1650 cars
# Scraping page # 66
# 1675 cars
# Scraping page # 67
# 1700 cars
# Scraping page # 68
# 1725 cars
# Scraping page # 69
# 1750 cars
# Scraping page # 70
# 1775 cars
# Scraping page # 71
# 1800 cars
# Scraping page # 72
# 1825 cars
# Scraping page # 73
# 1850 cars
# Scraping page # 74
# 1875 cars
# Scraping page # 75
# 1900 cars
# Scraping page # 76
# 1925 cars
# Scraping page # 77
# 1950 cars
# Scraping page # 78
# 1975 cars
# Scraping page # 79
# 2000 cars
# Scraping page # 80
# 2025 cars
# Scraping page # 81
# 2050 cars
# Scraping page # 82
# 2075 cars
# Scraping page # 83
# 2100 cars
# Scraping page # 84
# 2125 cars
# Scraping page # 85
# 2150 cars
# Scraping page # 86
# 2175 cars
# Scraping page # 87
# 2200 cars
# Scraping page # 88
# 2225 cars
# Scraping page # 89
# 2250 cars
# Scraping page # 90
# 2275 cars
# Scraping page # 91
# 2300 cars
# Scraping page # 92
# 2325 cars
# Scraping page # 93
# 2350 cars
# Scraping page # 94
# 2375 cars
# Scraping page # 95
# 2400 cars
# Scraping page # 96
# 2425 cars
# Scraping page # 97
# 2450 cars
# Scraping page # 98
# 2475 cars
# Scraping page # 99
# 2500 cars
# Scraping page # 100
# 2525 cars
# Scraping page # 101
# 2550 cars
# Scraping page # 102
# 2575 cars
# Scraping page # 103
# 2600 cars
# Scraping page # 104
# 2625 cars
# Scraping page # 105
# 2650 cars
# Scraping page # 106
# 2675 cars
# Scraping page # 107
# 2700 cars
# Scraping page # 108
# 2725 cars
# Scraping page # 109
# 2750 cars
# Scraping page # 110
# 2775 cars
# Scraping page # 111
# 2800 cars
# Scraping page # 112
# 2825 cars
# Scraping page # 113
# 2850 cars
# Scraping page # 114
# 2875 cars
# Scraping page # 115
# 2900 cars
# Scraping page # 116
# 2925 cars
# Scraping page # 117
# 2950 cars
# Scraping page # 118
# 2975 cars
# Scraping page # 119
# 3000 cars
# Scraping page # 120
# 3025 cars
# Scraping page # 121
# 3050 cars
# Scraping page # 122
# 3075 cars
# Scraping page # 123
# 3100 cars
# Scraping page # 124
# 3125 cars
# Scraping page # 125
# 3150 cars
# Scraping page # 126
# 3175 cars
# Scraping page # 127
# 3200 cars
# Scraping page # 128
# 3225 cars
# Scraping page # 129
# 3250 cars
# Scraping page # 130
# 3275 cars
# Scraping page # 131
# 3300 cars
# Scraping page # 132
# 3325 cars
# Scraping page # 133
# 3350 cars
# Scraping page # 134
# 3375 cars
# Scraping page # 135
# 3400 cars

# %%
path = !pwd

# %%
# pickle results
cars.to_pickle(path[0]+'/../data/vroom/'+datestr+'.pkl')
